# %%
import pandas as pd

# Read the text file
path_wos = "./raw_data/wos_tab_3105.txt"
path_scielo = "./raw_data/scielo_3105_tab.txt"
path_scopus = "./raw_data/scopus_3105.csv"
df_wos = pd.read_table(path_wos, delimiter='\t')  
df_scielo = pd.read_table(path_scielo, delimiter='\t')

df_scopus = pd.read_csv(path_scopus, delimiter =',')

common_columns = list(set(df_wos.columns) & set(df_scielo.columns))

# Create new dataframes with common columns
df_wos = df_wos[common_columns]
df_scielo = df_scielo[common_columns]

concat_df = pd.concat([df_wos, df_scielo])
print(concat_df.head(10))
print(len(concat_df))

print(df_scopus.columns)
# Out:
#    Z9                                                 OI                 DT  \
# 0   4               Duong, Huu-Thanh/0000-0002-2404-4214  Proceedings Paper
# 1   0                                                NaN  Proceedings Paper
# 2   0                                                NaN            Article
# 3   4                                                NaN  Proceedings Paper
# 4   6  Calvo, Hiram/0000-0003-2836-2102; Gelbukh, Ale...  Proceedings Paper
# 5   0                                                NaN  Proceedings Paper
# 6  10  Gelbukh, Alexander/0000-0001-7845-9039; Calvo,...  Proceedings Paper
# 7   0                                                NaN            Article
# 8   3                                                NaN            Article
# 9   2  Wang, Yanning/0000-0002-4263-3944; Harris, Dan...  Proceedings Paper
#
#                                                   SC  \
# 0                                   Computer Science
# 1                                   Computer Science
# 2                               Business & Economics
# 3  Computer Science; Engineering; Telecommunications
# 4                                   Computer Science
# 5                                   Computer Science
# 6                                   Computer Science
# 7              Information Science & Library Science
# 8                                   Computer Science
# 9                                   Computer Science
#
#                                                   BE  U2      EP  \
# 0                                Saeed, K; Snasel, V   1   197.0
# 1   Metais, E; Meziane, F; Horacek, H; Kapetanios, E   0   198.0
# 2                                                NaN   0   221.0
# 3                                                NaN   2   493.0
# 4                            Gelbukh, A; Morales, EF   3   173.0
# 5                                                NaN   1     NaN
# 6                                         Gelbukh, A   4   508.0
# 7                                                NaN  11    95.0
# 8                                                NaN  12    89.0
# 9  Wu, XT; Jermaine, C; Xiong, L; Hu, XH; Kotevsk...   0  3736.0
#
#                                   DI  \
# 0                                NaN
# 1       10.1007/978-3-030-80599-9_17
# 2    10.1016/j.indmarman.2022.10.002
# 3            10.1145/3368926.3369731
# 4                                NaN
# 5   10.1109/LA-CCI48322.2021.9769839
# 6                                NaN
# 7     10.1590/0103-37862015000100008
# 8         10.1007/s10844-021-00661-w
# 9  10.1109/BigData50022.2020.9378443
#
#                                                   AB    PY  ...          DA  \
# 0  In this paper, we develop a Vietnamese Questio...  2014  ...  2023-06-06
# 1  In order to justify rulings, legal documents n...  2021  ...  2023-06-06
# 2  We present a proof of concept for using automa...  2022  ...  2023-06-06
# 3  Legal and regulatory texts are ubiquitous and ...  2019  ...  2023-06-06
# 4  This work describes a Shallow Question Answeri...  2008  ...  2023-06-06
# 5  This article aims to evaluate the impact of di...  2021  ...  2023-06-06
# 6  Previous work has shown that modeling relation...  2009  ...  2023-06-06
# 7  Text mining techniques have been widely used t...  2015  ...  2023-06-06
# 8  Public information access services are provide...  2022  ...  2023-06-06
# 9  We detail the challenges and barriers in apply...  2020  ...  2023-06-06
#
#                                                   DE U1  \
# 0  Question Answering; QA; Legal Document; Law on...  1
# 1  Legal document; Text classification; Text segm...  0
# 2  Automated text analytics; Franchise disclosure...  0
# 3  Reference Extraction; Legal Text; Bidirectiona...  0
# 4                                                NaN  1
# 5  feature extraction; clustering; comparison; na...  1
# 6                                                NaN  0
# 7  Official Gazette Cachoeiro de Itapemirim; Inde...  1
# 8  Natural language processing; Text classificati...  5
# 9  natural language processing; data analysis; te...  0
#
#                                                   C1  \
# 0  [Huu-Thanh Duong; Bao-Quoc Ho] Univ Sci, Fac I...
# 1  [Lou, Andres; Kosseim, Leila] Concordia Univ, ...
# 2  [Lawrence, Benjamin; Wang, Yanqing; Alexander,...
# 3  [Ngo Xuan Bach; Nguyen Thi Thanh Thuy; Dang Ba...
# 4  [Monroy, Alfredo; Calvo, Hiram; Gelbukh, Alexa...
# 5  [Lima, Joao Pedro; Costa, Jose Alfredo; Araujo...
# 6  [Monroy, Alfredo; Calvo, Hiram; Gelbukh, Alexa...
# 7  [Xavier, Bruno Missi; da Silva, Alcione Dias] ...
# 8  [Flores, Arthur Marcal; Pavan, Matheus Camasmi...
# 9  [Harris, Daniel R.; Eisinger, Christian; Delch...
#
#                                           PU  \
# 0                     SPRINGER-VERLAG BERLIN
# 1       SPRINGER INTERNATIONAL PUBLISHING AG
# 2                       ELSEVIER SCIENCE INC
# 3                  ASSOC COMPUTING MACHINERY
# 4                     SPRINGER-VERLAG BERLIN
# 5                                       IEEE
# 6                     SPRINGER-VERLAG BERLIN
# 7  PONTIFICIA UNIVERSIDADE CATOLICA CAMPINAS
# 8                                   SPRINGER
# 9                                       IEEE
#
#                                                   AU  \
# 0                                  Duong, HT; Ho, BQ
# 1       Lou, A; Salaun, O; Westermann, H; Kosseim, L
# 2      Lawrence, B; Wang, YQ; Pan, YH; Alexander, CS
# 3  Bach, NX; Thuy, NTT; Chien, DB; Duy, TK; Hien,...
# 4                    Monroy, A; Calvo, H; Gelbukh, A
# 5                    Lima, JP; Costa, JA; Araujo, DC
# 6                    Monroy, A; Calvo, H; Gelbukh, A
# 7               Xavier, BM; da Silva, AD; Gomes, GRR
# 8                 Flores, AM; Pavan, MC; Paraboni, I
# 9      Harris, DR; Eisinger, C; Wang, YN; Delcher, C
#
#                                                   RI       PD  \
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NOV
# 3                                                NaN      NaN
# 4  Calvo, Hiram/J-5773-2019; Gelbukh, Alexander/A...      NaN
# 5                                                NaN      NaN
# 6  Gelbukh, Alexander/A-8979-2008; Calvo, Hiram/J...      NaN
# 7                                                NaN  JAN-APR
# 8                      Paraboni, Ivandre/C-1550-2012      FEB
# 9                                                NaN      NaN
#
#                                                   TI  \
# 0  A Vietnamese Question Answering System in Viet...
# 1  Extracting Facts from Case Rulings Through Par...
# 2  An overview, empirical application, and discus...
# 3  Reference Extraction from Vietnamese Legal Doc...
# 4  Using Graphs for Shallow Question Answering on...
# 5  Comparison of Feature Extraction Methods for B...
# 6  NLP for Shallow Question Answering of Legal Do...
# 7  A hybrid architecture for document indexing of...
# 8  User profiling and satisfaction inference in p...
# 9  Challenges and Barriers in Applying Natural La...
#
#                                                   CR
# 0  Gospodnetic A., 2005, LUCENE ACTION; Le Thi, B...
# 1  Attardi Giuseppe, 2006, P 10 C COMP NAT LANG, ...
# 2  Aebi V, 2012, J BANK FINANC, V36, P3213, DOI 1...
# 3  Bohnet B, 2018, PROCEEDINGS OF THE 56TH ANNUAL...
# 4  ANNE RD, 2004, WORKSH QUEST ANSW RE, P2; DOANN...
# 5                                                NaN
# 6  ALFREDO M, 2008, LNCS, V5317, P165; ANNE RD, 2...
# 7  Anderson JD, 2001, INFORM PROCESS MANAG, V37, ...
# 8  Alvarez-Carmona M., 2015, CLEF 2015, P9; Ando ...
# 9  Andreu-Perez J, 2015, IEEE J BIOMED HEALTH, V1...
#
# [10 rows x 36 columns]
# 109
# Index(['Authors', 'Author(s) ID', 'Title', 'Year', 'Source title', 'Volume',
#        'Issue', 'Art. No.', 'Page start', 'Page end', 'Page count', 'Cited by',
#        'DOI', 'Link', 'Affiliations', 'Authors with affiliations', 'Abstract',
#        'Author Keywords', 'Index Keywords', 'Molecular Sequence Numbers',
#        'Chemicals/CAS', 'Tradenames', 'Manufacturers', 'Funding Details',
#        'Funding Text 1', 'Funding Text 2', 'References',
#        'Correspondence Address', 'Editors', 'Sponsors', 'Publisher',
#        'Conference name', 'Conference date', 'Conference location',
#        'Conference code', 'ISSN', 'ISBN', 'CODEN', 'PubMed ID',
#        'Language of Original Document', 'Abbreviated Source Title',
#        'Document Type', 'Publication Stage', 'Open Access', 'Source', 'EID'],
#       dtype='object')

# %%
import numpy as np
from IPython.display import display
pd.options.display.max_columns = None

display(df_scopus.head(2))
display(df_wos.head(2))
display(df_scielo.head(2))

df_scopus = df_scopus.rename(columns={"Cited by": "TC", "Document Type": "DT", "References": "CR"})
# Out:
#                            Authors                          Author(s) ID  \
# 0  Puri M., Varde A.S., de Melo G.  57205619317;15124504600;23088528100;
# 1                  Van der Watt M.                          57193258812;
#
#                                                Title  Year  \
# 0      Commonsense based text mining on urban policy  2023
# 1  Discouraging the Demand That Fosters Sex Traff...  2023
#
#                         Source title Volume  Issue Art. No.  Page start  \
# 0  Language Resources and Evaluation     57    2.0      NaN       733.0
# 1                          Societies     13    4.0       94         NaN
#
#    Page end  Page count  Cited by                         DOI  \
# 0     763.0         NaN       1.0  10.1007/s10579-022-09584-6
# 1       NaN         NaN       1.0         10.3390/soc13040094
#
#                                                 Link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                         Affiliations  \
# 0  Allstate Insurance Company, Northfield Townshi...
# 1  National Center on Sexual Exploitation, Washin...
#
#                            Authors with affiliations  \
# 0  Puri, M., Allstate Insurance Company, Northfie...
# 1  Van der Watt, M., National Center on Sexual Ex...
#
#                                             Abstract  \
# 0  Local laws on urban policy, i.e., ordinances d...
# 1  Augmented intelligence—as the fusion of human ...
#
#                                      Author Keywords Index Keywords  \
# 0  Commonsense reasoning; Opinion mining; Ordinan...            NaN
# 1  artificial intelligence; augmented intelligenc...            NaN
#
#    Molecular Sequence Numbers Chemicals/CAS  Tradenames  Manufacturers  \
# 0                         NaN           NaN         NaN            NaN
# 1                         NaN           NaN         NaN            NaN
#
#                                      Funding Details  \
# 0  National Science Foundation, NSF: 2018575, 211...
# 1  U.S. Department of Justice, DOJ: :2020-75-CX-0011
#
#                                       Funding Text 1 Funding Text 2  \
# 0  Manish Puri was supported by a Graduate Teachi...            NaN
# 1  This research was funded by the U.S. Departmen...            NaN
#
#                                           References  \
# 0  Alkhammash, E.H., Jussila, J., Lytras, M.D., V...
# 1  (2000) Protocol to Prevent, Suppress and Punis...
#
#                               Correspondence Address Editors Sponsors  \
# 0  Varde, A.S.; Department of Computer Science, U...     NaN      NaN
# 1  Van der Watt, M.; National Center on Sexual Ex...     NaN      NaN
#
#                                   Publisher Conference name Conference date  \
# 0  Springer Science and Business Media B.V.             NaN             NaN
# 1                                      MDPI             NaN             NaN
#
#   Conference location  Conference code      ISSN ISBN CODEN  PubMed ID  \
# 0                 NaN              NaN  1574020X  NaN   NaN        NaN
# 1                 NaN              NaN  20754698  NaN   NaN        NaN
#
#   Language of Original Document Abbreviated Source Title Document Type  \
# 0                       English      Lang. Resour. Eval.       Article
# 1                       English                     Soc.       Article
#
#   Publication Stage            Open Access  Source                 EID
# 0             Final                    NaN  Scopus  2-s2.0-85125152191
# 1             Final  All Open Access, Gold  Scopus  2-s2.0-85153741947
#    Z9                                    OI                 DT  \
# 0   4  Duong, Huu-Thanh/0000-0002-2404-4214  Proceedings Paper
# 1   0                                   NaN  Proceedings Paper
#
#                  SC                                                BE U2  \
# 0  Computer Science                               Saeed, K; Snasel, V  1
# 1  Computer Science  Metais, E; Meziane, F; Horacek, H; Kapetanios, E  0
#
#       EP                            DI  \
# 0  197.0                           NaN
# 1  198.0  10.1007/978-3-030-80599-9_17
#
#                                                   AB    PY  IS      OA  \
# 0  In this paper, we develop a Vietnamese Questio...  2014 NaN  Bronze
# 1  In order to justify rulings, legal documents n...  2021 NaN     NaN
#
#                                                   SO  \
# 0  COMPUTER INFORMATION SYSTEMS AND INDUSTRIAL MA...
# 1  NATURAL LANGUAGE PROCESSING AND INFORMATION SY...
#
#                                                   EM  HC   HP  \
# 0           dhthanhqa@gmail.com; hbquoc@hcmus.edu.vn NaN  NaN
# 1  andres.lou@concordia.ca; olivier.salaun@umontr... NaN  NaN
#
#                     UT       VL       LA  \
# 0  WOS:000346243400019   8838.0  English
# 1  WOS:000884368500017  12801.0  English
#
#                                               PA      PI         SN PT  TC  \
# 0  HEIDELBERGER PLATZ 3, D-14197 BERLIN, GERMANY  BERLIN  0302-9743  C   4
# 1  GEWERBESTRASSE 11, CHAM, CH-6330, SWITZERLAND    CHAM  0302-9743  C   0
#
#    NR     BP          DA                                                 DE  \
# 0  13  186.0  2023-06-06  Question Answering; QA; Legal Document; Law on...
# 1  30  187.0  2023-06-06  Legal document; Text classification; Text segm...
#
#    U1                                                 C1  \
# 0   1  [Huu-Thanh Duong; Bao-Quoc Ho] Univ Sci, Fac I...
# 1   0  [Lou, Andres; Kosseim, Leila] Concordia Univ, ...
#
#                                      PU  \
# 0                SPRINGER-VERLAG BERLIN
# 1  SPRINGER INTERNATIONAL PUBLISHING AG
#
#                                              AU   RI   PD  \
# 0                             Duong, HT; Ho, BQ  NaN  NaN
# 1  Lou, A; Salaun, O; Westermann, H; Kosseim, L  NaN  NaN
#
#                                                   TI  \
# 0  A Vietnamese Question Answering System in Viet...
# 1  Extracting Facts from Case Rulings Through Par...
#
#                                                   CR
# 0  Gospodnetic A., 2005, LUCENE ACTION; Le Thi, B...
# 1  Attardi Giuseppe, 2006, P 10 C COMP NAT LANG, ...
#    Z9                                                 OI                DT  \
# 0   0                                                NaN  research-article
# 1   3  Oliveira, Lucas/0000-0003-1811-5087; Moro, Cla...  research-article
#
#             SC  BE  U2  EP                               DI  \
# 0  Linguistics NaN   1 NaN    10.35699/1983-3652.2022.37569
# 1      Nursing NaN   2 NaN  10.1590/1980-265x-tce-2017-0187
#
#                                                   AB    PY   IS    OA  \
# 0  Abstract This article aims to present the Synt...  2022  NaN  gold
# 1  ABSTRACT Objective: to reflect on the use of c...  2019  NaN  gold
#
#                               SO  EM  HC  HP                              UT  \
# 0                    Texto Livre NaN NaN NaN  SCIELO:S1983-36522022000100225
# 1  Texto & Contexto - Enfermagem NaN NaN NaN  SCIELO:S0104-07072019000100601
#
#      VL          LA   PA   PI         SN PT  TC  NR         BP  DA  \
# 0  15.0  Portuguese  NaN  NaN  1983-3652  J   0  18     e37569 NaN
# 1  28.0     English  NaN  NaN  1980-265X  J   2  43  e20170187 NaN
#
#                                                   DE  U1  \
# 0  Computational linguistics; Natural Language Pr...   1
# 1  Terminology; Nursing; Informatics; Controlled ...   0
#
#                                                   C1  \
# 0  [Guaranha, Manoel Francisco] Universidade Sant...
# 1  [Gomes, Denilsen Carvalho; Oliveira, Lucas Ema...
#
#                                                   PU  \
# 0        Universidade Federal de Minas Gerais - UFMG
# 1  Universidade Federal de Santa Catarina, Progra...
#
#                                                   AU   RI  PD  \
# 0  Pacheco, Willian Emerson Afonso; Guaranha, Man...  NaN NaN
# 1  Gomes, Denilsen Carvalho; Oliveira, Lucas Eman...  NaN NaN
#
#                                                   TI  \
# 0  Parser sintático para o português brasileiro: ...
# 1  USE OF COMPUTATIONAL TOOLS AS SUPPORT TO THE C...
#
#                                                   CR
# 0  CHOMSKY N., 2015, Estruturas sintáticas; CHOMS...
# 1  Albuquerque Lêda Maria, 2015, Rev. Bras. Enfer...
